# %%
import os
import sys
import urllib.request

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import json

# %%
# API 인증정보 설정
client_id = "0QF5tXiOrwFNKLekzOgj"
client_secret = "2hDNhF8Aic"
url = "https://openapi.naver.com/v1/datalab/shopping/categories";

# body 안의 내용
# - startDate: 조회기간 시작 날짜
# - endDate: 조회기간 종료 날짜
# - timeUnit: 구간 단위(date, week, month)
# - category: 쇼핑 분야 코드. 네이버쇼핑에서 카테고리를 선택했을 때의 URL에 있는 cat_id 파라미터의 값으로 분야 코드를 확인할 수 있음
# - keyword: 검색 키워드
# - device: 기기 검색 환경 (pc, mo)
# - gender: 성별 (m 남성, w 여성)
# - ages: 연령 (10~60 사이)

body = "{\"startDate\":\"2019-01-01\",\"endDate\":\"2022-10-31\",\"timeUnit\":\"month\", \
         \"category\":[{\"name\":\"물티슈\",\"param\":[\"50000117\"]}, \
                       {\"name\":\"마스크\",\"param\":[\"50002057\"]}, \
                       {\"name\":\"샴푸\",\"param\":[\"50000297\"]}], \
         \"device\":\"\", \"ages\":[], \"gender\":\"\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    query = response_body.decode('utf-8')
    print(query)
    data_query = json.loads(query)
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2019-01-01","endDate":"2022-10-31","timeUnit":"month","results":[{"title":"물티슈","category":["50000117"],"data":[{"period":"2019-01-01","ratio":0.66213},{"period":"2019-02-01","ratio":0.66222},{"period":"2019-03-01","ratio":0.90056},{"period":"2019-04-01","ratio":0.55077},{"period":"2019-05-01","ratio":0.71133},{"period":"2019-06-01","ratio":0.61536},{"period":"2019-07-01","ratio":0.63082},{"period":"2019-08-01","ratio":0.75162},{"period":"2019-09-01","ratio":0.73543},{"period":"2019-10-01","ratio":0.61064},{"period":"2019-11-01","ratio":0.55692},{"period":"2019-12-01","ratio":0.53531},{"period":"2020-01-01","ratio":0.61847},{"period":"2020-02-01","ratio":0.88995},{"period":"2020-03-01","ratio":0.98452},{"period":"2020-04-01","ratio":0.70719},{"period":"2020-05-01","ratio":0.81456},{"period":"2020-06-01","ratio":0.77964},{"period":"2020-07-01","ratio":0.78386},{"period":"2020-08-01","ratio":0.77862},{"period":"2020-09-01","ratio":0.68749},{"period":"2020-10-01","ratio":0
# ...

# %%
dates = []
wettissue_data = []
for i in data_query['results'][0]['data']:
    dates.append(i['period'])
    wettissue_data.append(i['ratio'])
    
mask_data = []
for i in data_query['results'][1]['data']:
    mask_data.append(i['ratio'])

shampoo_data = []
for i in data_query['results'][2]['data']:
    shampoo_data.append(i['ratio'])
    
df1 = pd.DataFrame([dates, wettissue_data, mask_data, shampoo_data]).T
df1.columns = ['Date', 'WetTissue', 'Mask', 'Shampoo']
df1
# Out:
#           Date WetTissue      Mask  Shampoo
# 0   2019-01-01   0.66213   2.07532  1.93409
# 1   2019-02-01   0.66222   0.88453  1.53928
# 2   2019-03-01   0.90056    6.4582  1.64664
# 3   2019-04-01   0.55077   0.71351  1.55176
# 4   2019-05-01   0.71133   0.47408  1.64314
# 5   2019-06-01   0.61536   0.50464  1.80212
# 6   2019-07-01   0.63082   1.08087  1.94925
# 7   2019-08-01   0.75162   0.36511  1.89989
# 8   2019-09-01   0.73543   1.53585  1.76811
# 9   2019-10-01   0.61064   1.31481  1.86073
# 10  2019-11-01   0.55692   0.57315  2.32178
# 11  2019-12-01   0.53531   0.96838  2.35862
# 12  2020-01-01   0.61847  19.32476  2.08056
# 13  2020-02-01   0.88995       100  2.07761
# 14  2020-03-01   0.98452  73.17109  2.34559
# 15  2020-04-01   0.70719  16.21894  2.08432
# 16  2020-05-01   0.81456  27.86074  2.05763
# 17  2020-06-01   0.77964  24.02306  2.20872
# 18  2020-07-01   0.78386  19.19997  2.31438
# 19  2020-08-01   0.77862  23.15357  2.55166
# ...

# %%
# API 인증정보 설정
client_id = "0QF5tXiOrwFNKLekzOgj"
client_secret = "2hDNhF8Aic"
url = "https://openapi.naver.com/v1/datalab/shopping/categories";

# body 안의 내용
# - startDate: 조회기간 시작 날짜
# - endDate: 조회기간 종료 날짜
# - timeUnit: 구간 단위(date, week, month)
# - category: 쇼핑 분야 코드. 네이버쇼핑에서 카테고리를 선택했을 때의 URL에 있는 cat_id 파라미터의 값으로 분야 코드를 확인할 수 있음
# - keyword: 검색 키워드
# - device: 기기 검색 환경 (pc, mo)
# - gender: 성별 (m 남성, w 여성)
# - ages: 연령 (10~60 사이)

body = "{\"startDate\":\"2019-01-01\",\"endDate\":\"2022-10-31\",\"timeUnit\":\"month\", \
         \"category\":[{\"name\":\"오메가3\",\"param\":[\"50002447\"]}, \
                       {\"name\":\"내셔널지오그래픽패딩\",\"param\":[\"50000837\"]}, \
                       {\"name\":\"나이키운동화\",\"param\":[\"50000788\"]}], \
         \"device\":\"\", \"ages\":[], \"gender\":\"\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    query = response_body.decode('utf-8')
    print(query)
    data_query = json.loads(query)
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2019-01-01","endDate":"2022-10-31","timeUnit":"month","results":[{"title":"오메가3","category":["50002447"],"data":[{"period":"2019-01-01","ratio":2.53916},{"period":"2019-02-01","ratio":2.09052},{"period":"2019-03-01","ratio":3.28553},{"period":"2019-04-01","ratio":3.11702},{"period":"2019-05-01","ratio":5.12498},{"period":"2019-06-01","ratio":4.85277},{"period":"2019-07-01","ratio":6.05629},{"period":"2019-08-01","ratio":6.87625},{"period":"2019-09-01","ratio":8.34339},{"period":"2019-10-01","ratio":7.58567},{"period":"2019-11-01","ratio":9.79129},{"period":"2019-12-01","ratio":12.26585},{"period":"2020-01-01","ratio":11.60985},{"period":"2020-02-01","ratio":9.04974},{"period":"2020-03-01","ratio":8.86404},{"period":"2020-04-01","ratio":8.20011},{"period":"2020-05-01","ratio":7.62221},{"period":"2020-06-01","ratio":6.55504},{"period":"2020-07-01","ratio":6.04294},{"period":"2020-08-01","ratio":4.14219},{"period":"2020-09-01","ratio":4.22129},{"period":"2020-10-01","ratio
# ...

# %%
omega3_data = []
for i in data_query['results'][0]['data']:
    omega3_data.append(i['ratio'])
    
national_data = []
for i in data_query['results'][1]['data']:
    dates.append(i['period'])
    national_data.append(i['ratio'])

nike_data = []
for i in data_query['results'][2]['data']:
    nike_data.append(i['ratio'])

df2 = pd.DataFrame([omega3_data, national_data, nike_data]).T
df2.columns = ['Omega3', 'NationalGeographic', 'Nike']
df2
# Out:
#       Omega3  NationalGeographic      Nike
# 0    2.53916            34.85331  18.53460
# 1    2.09052            16.88162  21.06782
# 2    3.28553            13.90070  22.38283
# 3    3.11702             8.08272  20.02252
# 4    5.12498             3.32740  19.81175
# 5    4.85277             2.29096  16.50768
# 6    6.05629             3.09402  17.05898
# 7    6.87625             6.10742  17.72974
# 8    8.34339            15.80625  24.42239
# 9    7.58567            39.62642  25.27938
# 10   9.79129           100.00000  25.64853
# 11  12.26585            86.96940  25.13024
# 12  11.60985            37.90496  27.03059
# 13   9.04974            22.03030  29.04238
# 14   8.86404            18.13363  32.01403
# 15   8.20011            12.63289  31.11782
# 16   7.62221             6.53582  30.46742
# 17   6.55504             2.99918  22.11327
# 18   6.04294             3.73919  19.79466
# 19   4.14219             6.18081  18.36288
# 20   4.22129            16.36366  21.22724
# ...

# %%
# API 인증정보 설정
client_id = "0QF5tXiOrwFNKLekzOgj"
client_secret = "2hDNhF8Aic"
url = "https://openapi.naver.com/v1/datalab/shopping/categories";

# body 안의 내용
# - startDate: 조회기간 시작 날짜
# - endDate: 조회기간 종료 날짜
# - timeUnit: 구간 단위(date, week, month)
# - category: 쇼핑 분야 코드. 네이버쇼핑에서 카테고리를 선택했을 때의 URL에 있는 cat_id 파라미터의 값으로 분야 코드를 확인할 수 있음
# - keyword: 검색 키워드
# - device: 기기 검색 환경 (pc, mo)
# - gender: 성별 (m 남성, w 여성)
# - ages: 연령 (10~60 사이)

body = "{\"startDate\":\"2019-01-01\",\"endDate\":\"2022-10-31\",\"timeUnit\":\"month\", \
         \"category\":[{\"name\":\"포켓몬빵\",\"param\":[\"50000149\"]}, \
                       {\"name\":\"아이폰\",\"param\":[\"50001519\"]}], \
         \"device\":\"\", \"ages\":[], \"gender\":\"\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    query = response_body.decode('utf-8')
    print(query)
    data_query = json.loads(query)
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2019-01-01","endDate":"2022-10-31","timeUnit":"month","results":[{"title":"포켓몬빵","category":["50000149"],"data":[{"period":"2019-01-01","ratio":32.18244},{"period":"2019-02-01","ratio":32.02583},{"period":"2019-03-01","ratio":32.82346},{"period":"2019-04-01","ratio":29.76936},{"period":"2019-05-01","ratio":28.58545},{"period":"2019-06-01","ratio":29.15926},{"period":"2019-07-01","ratio":27.48441},{"period":"2019-08-01","ratio":27.95421},{"period":"2019-09-01","ratio":31.38576},{"period":"2019-10-01","ratio":38.71997},{"period":"2019-11-01","ratio":40.16925},{"period":"2019-12-01","ratio":36.78609},{"period":"2020-01-01","ratio":39.31682},{"period":"2020-02-01","ratio":50.4858},{"period":"2020-03-01","ratio":52.33058},{"period":"2020-04-01","ratio":41.17257},{"period":"2020-05-01","ratio":35.08478},{"period":"2020-06-01","ratio":31.44933},{"period":"2020-07-01","ratio":33.39239},{"period":"2020-08-01","ratio":32.72949},{"period":"2020-09-01","ratio":41.28461},{"period":"
# ...

# %%
pokemon_data = []
for i in data_query['results'][0]['data']:
    pokemon_data.append(i['ratio'])

iphone_data = []
for i in data_query['results'][1]['data']:
    iphone_data.append(i['ratio'])
    
df3 = pd.DataFrame([pokemon_data, iphone_data]).T
df3.columns = ['PokemonBread', 'iPhone']
df3
# Out:
#     PokemonBread    iPhone
# 0       32.18244   0.98396
# 1       32.02583   1.57132
# 2       32.82346   2.10071
# 3       29.76936   1.61800
# 4       28.58545   1.49712
# 5       29.15926   1.54392
# 6       27.48441   2.09457
# 7       27.95421   2.71683
# 8       31.38576   2.60230
# 9       38.71997   2.95886
# 10      40.16925   3.42618
# 11      36.78609   3.69177
# 12      39.31682   3.77455
# 13      50.48580   5.12512
# 14      52.33058   6.12034
# 15      41.17257   6.13817
# 16      35.08478   8.24670
# 17      31.44933   6.61605
# 18      33.39239   8.31032
# 19      32.72949  12.34569
# 20      41.28461  10.41262
# 21      41.70629  12.78398
# 22      48.28863  18.15481
# 23      50.83122  17.11180
# 24      52.04002  18.06203
# 25      47.39550  13.10167
# 26      44.49892  13.32463
# 27      40.07101  13.29445
# 28      40.73907  13.70868
# 29      36.88319  13.18803
# 30      35.36310  14.61322
# 31      38.98319  20.56422
# 32      42.99236  20.92179
# ...

# %%
df1['WetTissue'] = df1['WetTissue'].astype(float)
df1['Mask'] = df1['Mask'].astype(float)
df1['Shampoo'] = df1['Shampoo'].astype(float)
df2['Omega3'] = df2['Omega3'].astype(float)
df2['NationalGeographic'] = df2['NationalGeographic'].astype(float)
df2['Nike'] = df2['Nike'].astype(float)
df3['PokemonBread'] = df3['PokemonBread'].astype(float)
df3['iPhone'] = df3['iPhone'].astype(float)

# %%
df = pd.concat([df1, df2, df3], axis=1)
df
# Out:
#           Date  WetTissue       Mask  Shampoo    Omega3  NationalGeographic  \
# 0   2019-01-01    0.66213    2.07532  1.93409   2.53916            34.85331
# 1   2019-02-01    0.66222    0.88453  1.53928   2.09052            16.88162
# 2   2019-03-01    0.90056    6.45820  1.64664   3.28553            13.90070
# 3   2019-04-01    0.55077    0.71351  1.55176   3.11702             8.08272
# 4   2019-05-01    0.71133    0.47408  1.64314   5.12498             3.32740
# 5   2019-06-01    0.61536    0.50464  1.80212   4.85277             2.29096
# 6   2019-07-01    0.63082    1.08087  1.94925   6.05629             3.09402
# 7   2019-08-01    0.75162    0.36511  1.89989   6.87625             6.10742
# 8   2019-09-01    0.73543    1.53585  1.76811   8.34339            15.80625
# 9   2019-10-01    0.61064    1.31481  1.86073   7.58567            39.62642
# 10  2019-11-01    0.55692    0.57315  2.32178   9.79129           100.00000
# ...

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 11
plt.figure(figsize=(12, 8))

plt.plot(df['Date'], df['WetTissue'])
plt.plot(df['Date'], df['Mask'])
plt.plot(df['Date'], df['Shampoo'])
plt.plot(df['Date'], df['Omega3'])

plt.legend(['물티슈', '마스크', '샴푸', '오메가3'])
plt.title('네이버 쇼핑인사이트 API')
plt.xticks([0, 13, 25, 37, 45], labels=['2019년', '2020년', '2021년', '2022년',  '2022년 10월'], fontsize=12)
# Out:
# ([<matplotlib.axis.XTick at 0x20bbf4efa30>,
# ...
#  [Text(0, 0, '2019년'),
#   Text(13, 0, '2020년'),
#   Text(25, 0, '2021년'),
#   Text(37, 0, '2022년'),
#   Text(45, 0, '2022년 10월')])

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 11
plt.figure(figsize=(12, 8))

plt.plot(df['Date'], df['NationalGeographic'])
plt.plot(df['Date'], df['Nike'])
plt.plot(df['Date'], df['PokemonBread'])
plt.plot(df['Date'], df['iPhone'])

plt.legend(['내셔널지오그래픽패딩', '나이키운동화', '포켓몬빵', '아이폰'])
plt.title('네이버 쇼핑인사이트 API')
plt.xticks([0, 13, 25, 37, 45], labels=['2019년', '2020년', '2021년', '2022년', '2022년 10월'], fontsize=12)
# Out:
# ([<matplotlib.axis.XTick at 0x20bbf5ca190>,
# ...
#  [Text(0, 0, '2019년'),
#   Text(13, 0, '2020년'),
#   Text(25, 0, '2021년'),
#   Text(37, 0, '2022년'),
#   Text(45, 0, '2022년 10월')])

# %%
os.chdir('./Data/')

# %%
df.to_csv('네이버 쇼핑인사이트 8가지 품목 클릭량.csv',index=False)
